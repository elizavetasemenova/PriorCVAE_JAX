# %% [markdown]
# ## Run MCMC inference using GP model

# %%
import random
import time

import tikzplotlib
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
import jax
import jax.numpy as jnp
import numpyro.distributions as npdist
import numpyro
from numpyro.infer import Predictive, init_to_median, MCMC, NUTS
import pickle

import jax.config as config
config.update("jax_enable_x64", True)

from priorCVAE.priors import Matern52, SquaredExponential
#from experiments.zimbabwe.zimbabwe_utility import read_data
from experiments.zimbabwe_utility import read_data

# %%
data_path = "../../zimbabwe/data/zwe2016phia.geojson"
num_warmup = 2000
#num_samples = 100000
num_samples = 50000
num_chains = 2

# %% [markdown]
# ## Load Data

# %%
data = gpd.read_file(data_path)

fig, ax = plt.subplots(1, 1, figsize=(4,4))
data.plot(column='area_id', ax=ax, legend=False)

plt.show()

# %%
x, data_centroid = read_data(data_path, normalize=False)
# Out:
# /Users/es/Dropbox/00 Oxford/96_cvae_jax_port/PriorCVAE_JAX/experiments/zimbabwe_utility.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   data_frame["centroid"] = data_frame["geometry"].centroid
# /Users/es/Dropbox/00 Oxford/96_cvae_jax_port/PriorCVAE_JAX/experiments/zimbabwe_utility.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   temp_centroids = data_frame["geometry"].centroid

# %%
## Adding estimate data
data_centroid["estimate"] = data["estimate"]

# %%
fig, ax = plt.subplots(1, 1, figsize=(6,6))
data_centroid.plot(column='estimate', ax=ax, legend=True, cmap='plasma')
data_centroid["centroid"].plot(ax=ax, color="DarkBlue", marker="x")
plt.show()

# %%
def model_centroids(x, n_obs=None, kernel=Matern52(), y=None):
    
    # fixed effects
    b0 = numpyro.sample('b0', npdist.Normal(0, 1))
     
    lengthscale = numpyro.sample("lengthscale", npdist.Gamma(2,4)) 
    #lengthscale = numpyro.sample("lengthscale", npdist.Uniform(0,3)) 
    #lengthscale = numpyro.sample("lengthscale", npdist.Uniform(0.5,4)) 
    #lengthscale = numpyro.sample("lengthscale", npdist.Uniform(0.2,4)) 
    kernel.lengthscale = lengthscale
    k = kernel(x, x)
    
    kernel_var = numpyro.sample("variance", npdist.Gamma(1.5, 1.5)) 
    N = x.shape[0]
    re_std = numpyro.sample('re_std', npdist.MultivariateNormal(loc=jnp.zeros(N), covariance_matrix=k))
    re = numpyro.deterministic('re', kernel_var * re_std)
    
    # linear predictor
    lp = b0 + re
    theta = numpyro.deterministic("theta", jax.nn.sigmoid(lp))
    
    numpyro.sample("obs", npdist.BinomialLogits(total_count = n_obs, logits=lp), obs=y)

# %% [markdown]
# ## Observations

# %%
data['y'] = round(data['y']).astype(int)
data['n_obs'] = round(data['n_obs']).astype(int)

# %% [markdown]
# ## GP Prior

# %%
rng_key, rng_key_ = jax.random.split(jax.random.PRNGKey(random.randint(0, 9999)))
gp_predictive = Predictive(model_centroids, num_samples=5000)
gp_preds = gp_predictive(rng_key_, x=x, n_obs = jnp.array(data.n_obs))

ls_prior_draws = gp_preds['lengthscale']
plt.hist(ls_prior_draws, bins=100)
plt.title('lengthscale, prior draws')
plt.show()

kernel_var_prior = gp_preds['variance']
plt.hist(kernel_var_prior, bins=100)
plt.title('var, prior draws')
plt.show()

# %% [markdown]
# ## MCMC Inference using GP Prior

# %%
#fname = 'zimbabwe_gp_mcmc_Matern52_U02.pkl'
#fname = 'zimbabwe_gp_mcmc_Matern52_U03.pkl'
#fname = 'zimbabwe_gp_mcmc_Matern52_U04.pkl'
fname = 'zimbabwe_gp_mcmc_Matern52_Gamma_2_4.pkl'

rng_key, rng_key_predict = jax.random.split(jax.random.PRNGKey(random.randint(0, 999999)))

# inference
start = time.time()
kernel = NUTS(model_centroids)
mcmc_gp = MCMC(kernel, num_warmup=num_warmup, num_samples=num_samples, num_chains=num_chains)
mcmc_gp.run(rng_key, x=x, n_obs = jnp.array(data.n_obs), y = jnp.array(data.y))
t_elapsed = time.time() - start
# Out:
# /var/folders/q3/n2z18__9281b8xfhctcpxfsr0000gn/T/ipykernel_10253/2594593233.py:11: UserWarning: There are not enough devices to run parallel chains: expected 2 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(2)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc_gp = MCMC(kernel, num_warmup=num_warmup, num_samples=num_samples, num_chains=num_chains)
# sample: 100%|██████████| 52000/52000 [16:46<00:00, 51.64it/s, 31 steps of size 7.59e-02. acc. prob=0.77]
# sample: 100%|██████████| 52000/52000 [13:11<00:00, 65.74it/s, 31 steps of size 8.89e-02. acc. prob=0.70]

# %%
with open(fname, 'wb') as f:
    pickle.dump(mcmc_gp, f)

# %%
mcmc_gp.print_summary(exclude_deterministic=False)
mcmc_gp_samples = mcmc_gp.get_samples()
# Out:
#                    mean       std    median      5.0%     95.0%     n_eff     r_hat
#            b0     -1.79      0.17     -1.80     -2.07     -1.54    500.10      1.00
#   lengthscale      1.13      0.28      1.09      0.65      1.57    320.19      1.01
#         re[0]      0.22      0.18      0.22     -0.07      0.51    625.35      1.00
#         re[1]     -0.03      0.18     -0.03     -0.31      0.27    593.82      1.00
#         re[2]     -0.09      0.18     -0.09     -0.37      0.21    596.44      1.00
#         re[3]     -0.32      0.21     -0.31     -0.66      0.03    750.93      1.00
#         re[4]     -0.47      0.24     -0.46     -0.86     -0.08   1018.88      1.00
#         re[5]     -0.27      0.22     -0.27     -0.63      0.08    710.68      1.00
#         re[6]     -0.28      0.21     -0.27     -0.64      0.05    560.51      1.00
#         re[7]     -0.44      0.21     -0.43     -0.77     -0.11    713.48      1.00
#         re[8]     -0.51      0.24     -0.50     -0.91     -0.14    840.40      1.00
#         re[9]     -0.36      0.25     -0.35     -0.74      0.05    628.07      1.01
#        re[10]     -0.14      0.20     -0.14     -0.47      0.18    723.02      1.00
#        re[11]     -0.15      0.21     -0.15     -0.47      0.21    800.49      1.00
#        re[12]     -0.11      0.21     -0.10     -0.45      0.24    684.31      1.00
#        re[13]     -0.03      0.20     -0.03     -0.36      0.29    588.17      1.00
#        re[14]     -0.23      0.24     -0.22     -0.61      0.17    937.55      1.00
#        re[15]     -0.24      0.20     -0.23     -0.58      0.10    866.94      1.00
#        re[16]     -0.40      0.23     -0.39     -0.77     -0.01   1202.06      1.00
#        re[17]     -0.24      0.20     -0.24     -0.57      0.11    818.25      1.00
#        re[18]      0.08      0.21      0.08     -0.24      0.45    932.97      1.00
#     theta[49]      0.21      0.02      0.21      0.18      0.25   2967.92      1.00
#     theta[50]      0.19      0.02      0.19      0.16      0.22   3706.77      1.00
#     theta[51]      0.19      0.02      0.19      0.15      0.23   3640.52      1.00
#     theta[52]      0.19      0.03      0.19      0.14      0.23   3473.79      1.00
#     theta[53]      0.18      0.02      0.18      0.15      0.21  11990.89      1.00
#     theta[54]      0.18      0.02      0.17      0.15      0.20  20407.06      1.00
#     theta[55]      0.14      0.02      0.14      0.11      0.17   6648.19      1.00
#     theta[56]      0.08      0.01      0.08      0.05      0.10   6950.34      1.00
#     theta[57]      0.11      0.01      0.11      0.09      0.13   7574.27      1.00
#     theta[58]      0.14      0.01      0.14      0.12      0.17   3292.24      1.00
#     theta[59]      0.14      0.01      0.14      0.12      0.16  14792.41      1.00
#     theta[60]      0.18      0.02      0.18      0.15      0.21   6678.09      1.00
#     theta[61]      0.14      0.02      0.14      0.11      0.17   5930.89      1.00
#     theta[62]      0.16      0.02      0.16      0.13      0.19   8100.36      1.00
#      variance      0.40      0.09      0.39      0.27      0.53    501.58      1.00
#
# Number of divergences: 10523

# %%
print("\nMCMC elapsed time:", round(t_elapsed), "s")

ss = numpyro.diagnostics.summary(mcmc_gp.get_samples(group_by_chain=True))
r = jnp.mean(ss['re']['n_eff'])
print("Average ESS for all REs : " + str(round(r)))
# Out:
# MCMC elapsed time: 1803 s
# Average ESS for all REs : 785

# %%
c_samps_gp = mcmc_gp_samples['lengthscale']

fig, ax = plt.subplots(1, 1, figsize=(6, 4))
plt.hist(c_samps_gp, density=True, label = 'posterior', bins=50, alpha=0.5)
plt.hist(ls_prior_draws, density=True, label = 'prior', bins=50, alpha=0.5)
# plt.title('lengthscale, prior and posterior')
plt.legend()
#plt.xlim([0, 3])

#tikzplotlib.save(r"lengthscale.tex",
#                 figurewidth='\\figurewidth', figureheight='\\figureheight',
#                 figure=fig)

# %%
c_samps_gp = mcmc_gp_samples['lengthscale']

fig, ax = plt.subplots(1, 1, figsize=(6, 4))
plt.hist(c_samps_gp, density=True, label = 'posterior', bins=50, alpha=0.5)
plt.hist(ls_prior_draws, density=True, label = 'prior', bins=50, alpha=0.5)
# plt.title('lengthscale, prior and posterior')
plt.legend()
#plt.xlim([0, 3])

#tikzplotlib.save(r"lengthscale.tex",
#                 figurewidth='\\figurewidth', figureheight='\\figureheight',
#                 figure=fig)

plt.show()

# %%
c_samps_gp = mcmc_gp_samples['lengthscale']

fig, ax = plt.subplots(1, 1, figsize=(6, 4))
plt.hist(c_samps_gp, density=True, label = 'posterior', bins=50, alpha=0.5)
plt.hist(ls_prior_draws, density=True, label = 'prior', bins=50, alpha=0.5)
# plt.title('lengthscale, prior and posterior')
plt.legend()
#plt.xlim([0, 3])

#tikzplotlib.save(r"lengthscale.tex",
#                 figurewidth='\\figurewidth', figureheight='\\figureheight',
#                 figure=fig)

plt.show()

# %%
c_samps_gp = mcmc_gp_samples['lengthscale']

fig, ax = plt.subplots(1, 1, figsize=(6, 4))
plt.hist(c_samps_gp, density=True, label = 'posterior', bins=50, alpha=0.5)
plt.hist(ls_prior_draws, density=True, label = 'prior', bins=50, alpha=0.5)
# plt.title('lengthscale, prior and posterior')
plt.legend()
#plt.xlim([0, 3])

#tikzplotlib.save(r"lengthscale.tex",
#                 figurewidth='\\figurewidth', figureheight='\\figureheight',
#                 figure=fig)

plt.show()

# %%
c_samps_gp = mcmc_gp_samples['lengthscale']

fig, ax = plt.subplots(1, 1, figsize=(6, 4))
plt.hist(c_samps_gp, density=True, label = 'posterior', bins=50, alpha=0.5)
plt.hist(ls_prior_draws, density=True, label = 'prior', bins=50, alpha=0.5)
# plt.title('lengthscale, prior and posterior')
plt.legend()
#plt.xlim([0, 3])

#tikzplotlib.save(r"lengthscale.tex",
#                 figurewidth='\\figurewidth', figureheight='\\figureheight',
#                 figure=fig)

plt.show()

# %%
c_samps_gp = mcmc_gp_samples['lengthscale']

fig, ax = plt.subplots(1, 1, figsize=(6, 4))
plt.hist(c_samps_gp, density=True, label = 'posterior', bins=50, alpha=0.5)
plt.hist(ls_prior_draws, density=True, label = 'prior', bins=50, alpha=0.5)
# plt.title('lengthscale, prior and posterior')
plt.legend()
plt.xlim([0, 3])

tikzplotlib.save(r"lengthscale.tex",
                 figurewidth='\\figurewidth', figureheight='\\figureheight',
                 figure=fig)

plt.show()

# %%
var_samps_gp = mcmc_gp_samples['variance']
plt.hist(var_samps_gp, density=True, label = 'posterior', bins=50, alpha=0.5)
plt.hist(kernel_var_prior, density=True, label = 'prior', bins=50, alpha=0.5)
# plt.title('kernel_var, prior and posterior')
plt.legend()
plt.xlim(0,3)

tikzplotlib.save(r"variance.tex",
                 figurewidth='\\figurewidth', figureheight='\\figureheight',
                 figure=fig)

plt.show()

# %%
# posterior predictive
posterior_predictive = Predictive(model_centroids, mcmc_gp_samples)(jax.random.PRNGKey(random.randint(0, 9999)), 
                                                                         x=x, 
                                                                         n_obs = jnp.array(data.n_obs))


theta_samps_gp = posterior_predictive['theta']
theta_mean_gp = theta_samps_gp.mean(axis=0)
bci_gp_25 = jnp.quantile(theta_samps_gp, 0.25, axis=0)
bci_gp_75 = jnp.quantile(theta_samps_gp, 0.75, axis=0)

data['theta_gp'] = theta_mean_gp

theta_observed = jnp.array(data['estimate'])
theta_estimated_gp = jnp.array(data['theta_gp'])

_max = np.max([theta_observed, theta_estimated_gp])
_min = np.min([theta_observed, theta_estimated_gp])

fig, ax = plt.subplots(1, 2, figsize=(12,6))
data.plot(column="estimate", ax=ax[0], cmap='plasma', vmin=_min, vmax =_max)
data.plot(column="theta_gp", ax=ax[1], cmap='plasma', vmin=_min, vmax =_max)

ax[0].axis("off")
ax[1].axis("off")
# Out:
# (24.8460406, 33.4588074, -22.7626307, -15.268733300000001)

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 5))
data.plot(column="estimate", ax=ax, cmap='plasma', vmin=_min, vmax =_max)
# data.plot(column="theta_gp", ax=ax[1], cmap='plasma', vmin=_min, vmax =_max)

plt.axis("off")
plt.tight_layout()
plt.savefig("estimate.pdf")
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 5))
data.plot(column="theta_gp", ax=ax, cmap='plasma', vmin=_min, vmax =_max)

plt.axis("off")
plt.tight_layout()
plt.savefig("gp_inference.pdf")
plt.show()
