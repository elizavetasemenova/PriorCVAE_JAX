# %% [markdown]
# ## Evaluate trained priorCVAE model

# %%
import random

import matplotlib.pyplot as plt
import jax
import jax.numpy as jnp
import flax.linen as nn
import jax.config as config
config.update("jax_enable_x64", True)

from priorCVAE.datasets import GPDataset
from priorCVAE.priors import SquaredExponential, Matern32, Matern52
from priorCVAE.models import MLPDecoder, MLPDecoderTwoHeads
from priorCVAE.utility import load_model_params
from experiments.exp_utils import plot_decoder_samples

# %%
model_path = r"../outputs/trained_models/e7kvvkr0/model/"

hidden_dim = 60
latent_dim = 40
out_dim = 80
batch_size = 40
# activation = nn.leaky_relu

x0 = 0
x1 = 1

x = jnp.linspace(0, 1, out_dim)
decoder_params = load_model_params(model_path)["decoder"]

# %% [markdown]
# ## TwoHeadDecoder Plot

# %%
decoder = MLPDecoderTwoHeads(hidden_dim, out_dim)

# %%
plot_decoder_samples(decoder, decoder_params, .5, latent_dim, x, n=15, plot_mean=True)

# %% [markdown]
# ## Single head

# %%
def get_decoder_samples(ls, decoder, decoder_params):
    z_rng = jax.random.PRNGKey(random.randint(0, 9999))
    z = jax.random.normal(z_rng, (batch_size, latent_dim))

    c = ls * jnp.ones((z.shape[0], 1))
    z_c = jnp.concatenate([z, c], axis=-1)
    out = decoder.apply({'params': decoder_params}, z_c)
    
    return out

# %%
decoder = MLPDecoder(hidden_dim, out_dim)

# %%
test_ls_list = [.05, .1, .2, .4, .5, .6, .8, 1.]

# %%
for ls in test_ls_list:
    decoder_samples = get_decoder_samples(ls=ls, decoder=decoder, decoder_params=decoder_params)
    kernel = SquaredExponential(lengthscale=ls, variance=1.)
    
    true_kernel_gp_dataset = GPDataset(kernel, out_dim, x0, x1, sample_lengthscale=False)
    _, true_samples, _ = true_kernel_gp_dataset.simulatedata(batch_size)
    
    fig, axs = plt.subplots(1, 2, figsize=(15,4))
    for i in range(batch_size):
        axs[0].plot(x, decoder_samples[i], color="tab:blue", alpha=0.2)
        axs[1].plot(x, true_samples[i], color="tab:red", alpha=0.2)


    axs[0].set_xlim([x0, x1]) 
    axs[1].set_xlim([x0, x1]) 

    axs[0].set_ylim([-3, 3]) 
    axs[1].set_ylim([-3, 3]) 

    axs[0].set_title(f"Decoder samples (ls={ls})")
    axs[1].set_title(f"Kernel samples (ls={ls})")
    
#     plt.savefig("comparison.png")
    
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ScopeParamNotFoundError                   Traceback (most recent call last)
# Cell In[12], line 2
#       1 for ls in test_ls_list:
# ----> 2     decoder_samples = get_decoder_samples(ls=ls, decoder=decoder, decoder_params=decoder_params)
#       3     kernel = SquaredExponential(lengthscale=ls, variance=1.)
#       5     true_kernel_gp_dataset = GPDataset(kernel, out_dim, x0, x1, sample_lengthscale=False)
#
# Cell In[9], line 7, in get_decoder_samples(ls, decoder, decoder_params)
#       5 c = ls * jnp.ones((z.shape[0], 1))
#       6 z_c = jnp.concatenate([z, c], axis=-1)
# ----> 7 out = decoder.apply({'params': decoder_params}, z_c)
#       9 return out
#
#     [... skipping hidden 6 frame]
#
# File ~/projects/PriorCVAE_JAX/priorCVAE/models/decoder.py:43, in MLPDecoder.__call__(self, z)
#      41     z = nn.Dense(hidden_dim, name=f"dec_hidden_{i}")(z)
#      42     z = activation_fn(z)
# ---> 43 z = nn.Dense(self.out_dim, name="dec_out")(z)
#      44 return z
#
#     [... skipping hidden 2 frame]
#
# File ~/Homebrew/anaconda3/envs/prior_cvae/lib/python3.10/site-packages/flax/linen/linear.py:196, in Dense.__call__(self, inputs)
#     186 @compact
#     187 def __call__(self, inputs: Array) -> Array:
#     188   """Applies a linear transformation to the inputs along the last dimension.
#     189
#     190   Args:
#    (...)
#     194     The transformed input.
#     195   """
# --> 196   kernel = self.param('kernel',
#     197                       self.kernel_init,
#     198                       (jnp.shape(inputs)[-1], self.features),
#     199                       self.param_dtype)
#     200   if self.use_bias:
#     201     bias = self.param('bias', self.bias_init, (self.features,),
#     202                       self.param_dtype)
#
#     [... skipping hidden 1 frame]
#
# File ~/Homebrew/anaconda3/envs/prior_cvae/lib/python3.10/site-packages/flax/core/scope.py:844, in Scope.param(self, name, init_fn, unbox, *init_args)
#     842   if self.is_collection_empty('params'):
#     843     raise errors.ScopeCollectionNotFound('params', name, self.path_text)
# --> 844   raise errors.ScopeParamNotFoundError(name, self.path_text)
#     845 value = init_fn(self.make_rng('params'), *init_args)
#     846 self.put_variable('params', name, value)
#
# ScopeParamNotFoundError: Could not find parameter named "kernel" in scope "/dec_out". (https://flax.readthedocs.io/en/latest/api_reference/flax.errors.html#flax.errors.ScopeParamNotFoundError)
