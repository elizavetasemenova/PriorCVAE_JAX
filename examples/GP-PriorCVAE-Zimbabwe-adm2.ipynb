# %% [markdown]
# # Squared Exponential kernel Gaussian process - PriorCVAE
#
# ## Moedlling HIV prevalence in Zimbabwe

# %% [markdown]
# This is a demo notebook to showcase the usage of PriorCVAE model on a Gaussian process dataset which is generated using a SquaredExponential kernel.

# %%
import random as rnd

import numpy as np 
import matplotlib.pyplot as plt

# Nupmyro
import numpyro
from numpyro.infer import Predictive
from numpyro.diagnostics import hpdi
import numpyro.distributions as npdist
numpyro.set_host_device_count(4)

# JAX
import jax
import optax
from jax import random
import jax.numpy as jnp

from priorCVAE.models import MLPEncoder, MLPDecoder, VAE
from priorCVAE.priors import GP, SquaredExponential
from priorCVAE.mcmc import run_mcmc_vae, vae_mcmc_inference_model
from priorCVAE.datasets import GPDataset
from priorCVAE.trainer import VAETrainer
from priorCVAE.losses import SquaredSumAndKL

import jax.config as config
config.update("jax_enable_x64", True)

import geopandas as gpd

# %% [markdown]
# ### Configuration

# %%
args = {
        "conditional": True,
        
        # architecture
        "input_dim" : 63,
        "hidden_dim": 63,
        "latent_dim": 50,
        
        # VAE training    
        "batch_size": 1000,
        "num_iterations": 400,
        "learning_rate": 1e-3,
        "vae_var": 0.8,

        # MCMC inference
        "num_warmup": 1000,
        "num_mcmc_samples": 4000,
        "num_chains": 4,
        "thinning": 1,
       }

# %% [markdown]
# ### Load data

# %%
import os
os.getcwd()
# Out:
# '/Users/es/Dropbox/00 Oxford/96_cvae_jax_port/PriorCVAE_JAX/examples'

# %%
s = gpd.read_file("data/Zimbabwe_adm2/shapefile.shp")
s['area_id'] = s.index + 1
s = s[['area_id', 'geometry']]
print(s.head)

s["centroid"] = s["geometry"].centroid


#temp_centroids = s["geometry"].to_crs("EPSG:32735").centroid
temp_centroids = s["geometry"].centroid
centroids = gpd.GeoDataFrame()
centroids["x"] = temp_centroids.geometry.apply(lambda x: x.x)
centroids["y"] = temp_centroids.geometry.apply(lambda x: x.y)
x_coords = jnp.array(centroids["x"])
y_coords = jnp.array(centroids["y"])
coords = jnp.dstack((x_coords, y_coords))[0]
print(coords.shape)
fig, ax = plt.subplots(1, 1, figsize=(8,8))
#divider = make_axes_locatable(ax)
s.plot(column='area_id', ax=ax, legend=True, cmap='plasma')
s["centroid"].plot(ax=ax, color="DarkBlue", marker="x")
# Out:
# /var/folders/q3/n2z18__9281b8xfhctcpxfsr0000gn/T/ipykernel_43692/3515941784.py:4: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   s["centroid"] = s["geometry"].centroid
# /var/folders/q3/n2z18__9281b8xfhctcpxfsr0000gn/T/ipykernel_43692/3515941784.py:7: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   temp_centroids = s["geometry"].centroid
# Array([[ 28.55567707, -20.12180646],
#        [ 31.06283891, -18.01423639],
#        [ 31.15884468, -17.89534495],
#        [ 31.03329735, -17.94493883],
#        [ 31.05367328, -17.80877326],
#        [ 31.86828564, -19.44901572],
#        [ 32.72164024, -19.78410801],
#        [ 32.47381587, -20.49665822],
#        [ 32.62525067, -20.20334228],
#        [ 32.1826814 , -18.3623211 ]], dtype=float64)

# %%
s = gpd.read_file("data/Zimbabwe_adm2/shapefile.shp")
print(s.shape)
s['area_id'] = s.index + 1
s.head()
# Out:
# (91, 13)
#     shp_lng   shape_r       area_nm                       ge_cnct    ge_mtch  \
# 0  1.443444  0.047147      BULAWAYO    ZIMBABWE_BULAWAYO_BULAWAYO  ZWE_01_01
# 1  0.351006  0.004183   CHITUNGWIZA   ZIMBABWE_HARARE_CHITUNGWIZA  ZWE_10_03
# 2  0.270473  0.003014       EPWORTH       ZIMBABWE_HARARE_EPWORTH  ZWE_10_04
# 3  0.746951  0.016657  HARARE RURAL  ZIMBABWE_HARARE_HARARE RURAL  ZWE_10_01
# 4  1.420471  0.056271  HARARE URBAN  ZIMBABWE_HARARE_HARARE URBAN  ZWE_10_02
#
#     cntry_n   adm1_nm                                           adm2_nm  \
# 0  ZIMBABWE  BULAWAYO                                          Bulawayo
# 1  ZIMBABWE    HARARE                                       Chitungwiza
# 2  ZIMBABWE    HARARE  Epworth - Hatfield/Kutsaga Village/Mukuvisi East
# 3  ZIMBABWE    HARARE                                      Harare Rural
# 4  ZIMBABWE    HARARE                                            Harare
#
#   adm_lvl uscbcmn nso_cod         nso_nam  \
# 0       2     NaN      21  Bulawayo Urban
# 1       2     NaN     922     Chitungwiza
# 2       2     NaN     923         Epworth
# 3       2     NaN     901    Harare Rural
# 4       2     NaN     902    Harare Urban
#
#                                             geometry  area_id
# 0  POLYGON ((28.61307 -19.96846, 28.62308 -19.980...        1
# 1  POLYGON ((31.05611 -17.97929, 31.05642 -17.979...        2
# 2  POLYGON ((31.15485 -17.87186, 31.15815 -17.872...        3
# 3  POLYGON ((31.14291 -17.90218, 31.14259 -17.903...        4
# 4  POLYGON ((31.10149 -17.66559, 31.11538 -17.667...        5

# %%
fig, ax = plt.subplots(1, 1, figsize=(6,6))
s.plot(column='area_id', ax=ax, legend=False)
# Out:
# <Axes: >

# %%
s.columns
# Out:
# Index(['shp_lng', 'shape_r', 'area_nm', 'ge_cnct', 'ge_mtch', 'cntry_n',
#        'adm1_nm', 'adm2_nm', 'adm_lvl', 'uscbcmn', 'nso_cod', 'nso_nam',
#        'geometry', 'area_id'],
#       dtype='object')

# %%
s = s[['area_id', 'geometry']]
s["centroid"] = s["geometry"].centroid

fig, ax = plt.subplots(1, 1, figsize=(8,8))
#divider = make_axes_locatable(ax)
s.plot(column='area_id', ax=ax, legend=True, cmap='plasma')
s["centroid"].plot(ax=ax, color="DarkBlue", marker="x")
# Out:
# /var/folders/q3/n2z18__9281b8xfhctcpxfsr0000gn/T/ipykernel_43692/143597390.py:2: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   s["centroid"] = s["geometry"].centroid
# <Axes: >

# %%
#temp_centroids = s["geometry"].to_crs("EPSG:32735").centroid
temp_centroids = s["geometry"].centroid
centroids = gpd.GeoDataFrame()
centroids["x"] = temp_centroids.geometry.apply(lambda x: x.x)
centroids["y"] = temp_centroids.geometry.apply(lambda x: x.y)
x_coords = jnp.array(centroids["x"])
y_coords = jnp.array(centroids["y"])
coords = jnp.dstack((x_coords, y_coords))[0]
coords.shape
coords[0:10,:]
# Out:
# /var/folders/q3/n2z18__9281b8xfhctcpxfsr0000gn/T/ipykernel_43692/258168673.py:2: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   temp_centroids = s["geometry"].centroid
# Array([[ 28.55567707, -20.12180646],
#        [ 31.06283891, -18.01423639],
#        [ 31.15884468, -17.89534495],
#        [ 31.03329735, -17.94493883],
#        [ 31.05367328, -17.80877326],
#        [ 31.86828564, -19.44901572],
#        [ 32.72164024, -19.78410801],
#        [ 32.47381587, -20.49665822],
#        [ 32.62525067, -20.20334228],
#        [ 32.1826814 , -18.3623211 ]], dtype=float64)

# %%
s = gpd.read_file("data/Zimbabwe_adm2/shapefile.shp")
0
# Out:
# (91, 3)
# /var/folders/q3/n2z18__9281b8xfhctcpxfsr0000gn/T/ipykernel_43692/3217462260.py:2: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   s["centroid"] = s["geometry"].centroid
# 0

# %%
fig, ax = plt.subplots(1, 1, figsize=(6,6))
s.plot(column='area_id', ax=ax, legend=False)
# Out:
# (91, 13)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/prior_cvae/lib/python3.10/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File /opt/anaconda3/envs/prior_cvae/lib/python3.10/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/anaconda3/envs/prior_cvae/lib/python3.10/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'area_id'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 5
#       2 print(s.shape)
#       4 fig, ax = plt.subplots(1, 1, figsize=(6,6))
# ----> 5 s.plot(column='area_id', ax=ax, legend=False)
#
# File /opt/anaconda3/envs/prior_cvae/lib/python3.10/site-packages/geopandas/plotting.py:969, in GeoplotAccessor.__call__(self, *args, **kwargs)
#     967 kind = kwargs.pop("kind", "geo")
#     968 if kind == "geo":
# --> 969     return plot_dataframe(data, *args, **kwargs)
#     970 if kind in self._pandas_kinds:
#     971     # Access pandas plots
#     972     return PlotAccessor(data)(kind=kind, **kwargs)
#
# File /opt/anaconda3/envs/prior_cvae/lib/python3.10/site-packages/geopandas/plotting.py:730, in plot_dataframe(df, column, cmap, color, ax, cax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, categories, classification_kwds, missing_kwds, aspect, **style_kwds)
#     728             values = values.reindex(df.index)
#     729 else:
# --> 730     values = df[column]
#     732 if pd.api.types.is_categorical_dtype(values.dtype):
#     733     if categories is not None:
#
# File /opt/anaconda3/envs/prior_cvae/lib/python3.10/site-packages/geopandas/geodataframe.py:1475, in GeoDataFrame.__getitem__(self, key)
#    1469 def __getitem__(self, key):
#    1470     """
#    1471     If the result is a column containing only 'geometry', return a
#    1472     GeoSeries. If it's a DataFrame with any columns of GeometryDtype,
#    1473     return a GeoDataFrame.
#    1474     """
# -> 1475     result = super().__getitem__(key)
#    1476     # Custom logic to avoid waiting for pandas GH51895
#    1477     # result is not geometry dtype for multi-indexes
#    1478     if (
#    1479         pd.api.types.is_scalar(key)
#    1480         and key == ""
#    (...)
#    1483         and not is_geometry_type(result)
#    1484     ):
#
# File /opt/anaconda3/envs/prior_cvae/lib/python3.10/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File /opt/anaconda3/envs/prior_cvae/lib/python3.10/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'area_id'

# %%
s = s[['area_id', 'geometry', 'y', 'n_obs', 'estimate']]
s['y'] = round(s['y']).astype(int)
s['n_obs'] = round(s['n_obs']).astype(int)
s["centroid"] = s["geometry"].centroid
print(np.sum(np.isnan(s['n_obs'])))
print(s.shape)
s.head()
# Out:
# 0
# (63, 6)
# /var/folders/q3/n2z18__9281b8xfhctcpxfsr0000gn/T/ipykernel_64404/2991311570.py:4: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   s["centroid"] = s["geometry"].centroid
#    area_id                                           geometry    y  n_obs  \
# 0  ZWE_2_1  MULTIPOLYGON (((28.60837 -20.23077, 28.60534 -...  250   1520
# 1  ZWE_2_2  MULTIPOLYGON (((30.99973 -17.99862, 31.00954 -...   44    280
# 2  ZWE_2_3  MULTIPOLYGON (((31.13664 -17.92887, 31.13584 -...  148   1243
# 3  ZWE_2_4  MULTIPOLYGON (((31.72304 -19.02447, 31.73064 -...   28    265
# 4  ZWE_2_5  MULTIPOLYGON (((32.87748 -20.09961, 32.85814 -...   10    118
#
#    estimate                    centroid
# 0  0.164841  POINT (28.55557 -20.12184)
# 1  0.155943  POINT (31.06270 -18.01409)
# 2  0.119002  POINT (31.04900 -17.83975)
# 3  0.105219  POINT (31.86831 -19.44905)
# 4  0.086011  POINT (32.72163 -19.78411)

# %%
fig, ax = plt.subplots(1, 1, figsize=(8,8))
#divider = make_axes_locatable(ax)
s.plot(column='estimate', ax=ax, legend=True, cmap='plasma')
s["centroid"].plot(ax=ax, color="DarkBlue", marker="x")
# Out:
# <Axes: >

# %% [markdown]
# ### Prevalence model - centroids

# %%
def prev_model_centroids(x, n_obs=None, length=None, var=1, jitter=1.0e-5, gp_kernel=SquaredExponential(), y=None):
    
    # fixed effects
    b0 = numpyro.sample('b0', npdist.Normal(0, 1))
    
    if length==None:  
        length = numpyro.sample("length", npdist.Gamma(2,4)) 
    
    k = gp_kernel(x, x, var, length, jitter)
    
    kernel_var = numpyro.sample("kernel_var", npdist.Gamma(1.5, 1.5)) 
    N = x.shape[0]
    re_std = numpyro.sample('re_std', npdist.MultivariateNormal(loc=jnp.zeros(N), covariance_matrix=k))
    re = numpyro.deterministic('re', kernel_var * re_std)
    
    # linear predictor
    lp = b0 + re
    theta = numpyro.deterministic("theta", jax.nn.sigmoid(lp))
    
    numpyro.sample("obs", npdist.BinomialLogits(total_count = n_obs, logits=lp), obs=y)

# %%
#temp_centroids = s["geometry"].to_crs("EPSG:32735").centroid
temp_centroids = s["geometry"].centroid
centroids = gpd.GeoDataFrame()
centroids["x"] = temp_centroids.geometry.apply(lambda x: x.x)
centroids["y"] = temp_centroids.geometry.apply(lambda x: x.y)
x_coords = jnp.array(centroids["x"])
y_coords = jnp.array(centroids["y"])
coords = jnp.dstack((x_coords, y_coords))[0]
coords.shape
coords[0:10,:]
# Out:
# /var/folders/q3/n2z18__9281b8xfhctcpxfsr0000gn/T/ipykernel_64404/258168673.py:2: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   temp_centroids = s["geometry"].centroid
# Array([[ 28.55556585, -20.1218445 ],
#        [ 31.06270251, -18.0140921 ],
#        [ 31.04899536, -17.8397461 ],
#        [ 31.86830731, -19.44905166],
#        [ 32.72163308, -19.78411075],
#        [ 32.47464314, -20.49506232],
#        [ 32.18258581, -18.3626773 ],
#        [ 32.43056289, -19.2234944 ],
#        [ 32.70896355, -18.63946168],
#        [ 32.75779112, -17.93779249]], dtype=float64)

# %% [markdown]
# ### Prior predictive

# %%
rng_key, rng_key_ = random.split(random.PRNGKey(4))
gp_predictive = Predictive(prev_model_centroids, num_samples=5000)
gp_preds = gp_predictive(rng_key_, x=jnp.array(coords), n_obs = jnp.array(s.n_obs))

ls_prior_draws = gp_preds['length']
plt.hist(ls_prior_draws, bins=100)
plt.title('lengthscale, prior draws')
plt.show()

kernel_var_prior = gp_preds['kernel_var']
plt.hist(kernel_var_prior, bins=100)
plt.title('var, prior draws')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 3
#       1 rng_key, rng_key_ = random.split(random.PRNGKey(4))
#       2 gp_predictive = Predictive(prev_model_centroids, num_samples=5000)
# ----> 3 gp_preds = gp_predictive(rng_key_, x=jnp.array(coords), n_obs = jnp.array(s.n_obs))
#       5 ls_prior_draws = gp_preds['length']
#       6 plt.hist(ls_prior_draws, bins=100)
#
# File /opt/anaconda3/envs/prior_cvae/lib/python3.10/site-packages/numpyro/infer/util.py:1007, in Predictive.__call__(self, rng_key, *args, **kwargs)
#     997 """
#     998 Returns dict of samples from the predictive distribution. By default, only sample sites not
#     999 contained in `posterior_samples` are returned. This can be modified by changing the
#    (...)
#    1004 :param kwargs: model kwargs.
#    1005 """
#    1006 if self.batch_ndims == 0 or self.params == {} or self.guide is None:
# -> 1007     return self._call_with_params(rng_key, self.params, args, kwargs)
#    1008 elif self.batch_ndims == 1:  # batch over parameters
#    1009     batch_size = jnp.shape(tree_flatten(self.params)[0][0])[0]
#
# File /opt/anaconda3/envs/prior_cvae/lib/python3.10/site-packages/numpyro/infer/util.py:984, in Predictive._call_with_params(self, rng_key, params, args, kwargs)
#     973     posterior_samples = _predictive(
#     974         guide_rng_key,
#     975         guide,
#    (...)
#     981         model_kwargs=kwargs,
#     982     )
#     983 model = substitute(self.model, self.params)
# --> 984 return _predictive(
#     985     rng_key,
#     986     model,
#     987     posterior_samples,
#     988     self._batch_shape,
#     989     return_sites=self.return_sites,
#     990     infer_discrete=self.infer_discrete,
#     991     parallel=self.parallel,
#     992     model_args=args,
#     993     model_kwargs=kwargs,
#     994 )
#
# File /opt/anaconda3/envs/prior_cvae/lib/python3.10/site-packages/numpyro/infer/util.py:821, in _predictive(rng_key, model, posterior_samples, batch_shape, return_sites, infer_discrete, parallel, model_args, model_kwargs)
#     819 rng_key = rng_key.reshape((*batch_shape, 2))
#     820 chunk_size = num_samples if parallel else 1
# --> 821 return soft_vmap(
#     822     single_prediction, (rng_key, posterior_samples), len(batch_shape), chunk_size
#     823 )
#
# File /opt/anaconda3/envs/prior_cvae/lib/python3.10/site-packages/numpyro/util.py:410, in soft_vmap(fn, xs, batch_ndims, chunk_size)
#     404     xs = tree_map(
#     405         lambda x: jnp.reshape(x, prepend_shape + (chunk_size,) + jnp.shape(x)[1:]),
#     406         xs,
#     407     )
#     408     fn = vmap(fn)
# --> 410 ys = lax.map(fn, xs) if num_chunks > 1 else fn(xs)
#     411 map_ndims = int(num_chunks > 1) + int(chunk_size > 1)
#     412 ys = tree_map(
#     413     lambda y: jnp.reshape(
#     414         y, (int(np.prod(jnp.shape(y)[:map_ndims])),) + jnp.shape(y)[map_ndims:]
#     415     )[:batch_size],
#     416     ys,
#     417 )
#
#     [... skipping hidden 12 frame]
#
# File /opt/anaconda3/envs/prior_cvae/lib/python3.10/site-packages/numpyro/infer/util.py:795, in _predictive.<locals>.single_prediction(val)
#     786     pred_samples = _sample_posterior(
#     787         config_enumerate(condition(model, samples)),
#     788         first_available_dim,
#    (...)
#     792         **model_kwargs,
#     793     )
#     794 else:
# --> 795     model_trace = trace(
#     796         seed(substitute(masked_model, samples), rng_key)
#     797     ).get_trace(*model_args, **model_kwargs)
#     798     pred_samples = {name: site["value"] for name, site in model_trace.items()}
#     800 if return_sites is not None:
#
# File /opt/anaconda3/envs/prior_cvae/lib/python3.10/site-packages/numpyro/handlers.py:171, in trace.get_trace(self, *args, **kwargs)
#     163 def get_trace(self, *args, **kwargs):
#     164     """
#     165     Run the wrapped callable and return the recorded trace.
#     166
#    (...)
#     169     :return: `OrderedDict` containing the execution trace.
#     170     """
# --> 171     self(*args, **kwargs)
#     172     return self.trace
#
# File /opt/anaconda3/envs/prior_cvae/lib/python3.10/site-packages/numpyro/primitives.py:105, in Messenger.__call__(self, *args, **kwargs)
#     103     return self
#     104 with self:
# --> 105     return self.fn(*args, **kwargs)
#
# File /opt/anaconda3/envs/prior_cvae/lib/python3.10/site-packages/numpyro/primitives.py:105, in Messenger.__call__(self, *args, **kwargs)
#     103     return self
#     104 with self:
# --> 105     return self.fn(*args, **kwargs)
#
#     [... skipping similar frames: Messenger.__call__ at line 105 (2 times)]
#
# File /opt/anaconda3/envs/prior_cvae/lib/python3.10/site-packages/numpyro/primitives.py:105, in Messenger.__call__(self, *args, **kwargs)
#     103     return self
#     104 with self:
# --> 105     return self.fn(*args, **kwargs)
#
# Cell In[20], line 4, in prev_model_centroids(x, n_obs, length, var, jitter, gp_kernel, y)
#       1 def prev_model_centroids(x, n_obs=None, length=None, var=1, jitter=1.0e-5, gp_kernel=SquaredExponential(), y=None):
#       2
#       3     # fixed effects
# ----> 4     b0 = numpyro.sample('b0', npdist.Normal(0, 1))
#       6     if length==None:
#       7         length = numpyro.sample("length", npdist.Gamma(2,4))
#
# NameError: name 'npdist' is not defined

# %% [markdown]
# ### Generate data
#
# We generate the data using an SquaredExponential kernel with lengthscale that is uniformly sampled. We plot a sample from the GP and plot the trajectories and lengthscales.

# %%
kernel = SquaredExponential()

gp_data_generator = GPDataset(n_data=args["input_dim"], kernel=kernel, sample_lengthscale=True)

# %%
sample_x_train, sample_y_train, sample_ls_train = gp_data_generator.simulatedata(n_samples=1000)
x_test, y_test, ls_test = gp_data_generator.simulatedata(n_samples=1000)

# %%
fig, ax = plt.subplots(figsize=(4,3))
for i in range(15):
    if sample_ls_train[i] <= 0.2:
        col = 'orange'
    elif sample_ls_train[i] <= 0.6:
        col = 'green'
    else:
        col = 'blue'
    ax.plot(sample_x_train[i], sample_y_train[i], color=col)
ax.set_xlabel('$x$')
ax.set_ylabel('$y=f(x)$')
ax.set_title('Example GP trajectories')

plt.show()

# %%
# Plot sample lengthscales
plt.figure(figsize=(4,3))
plt.hist(sample_ls_train[:, 0], alpha = 0.3, label = 'train ls') 
plt.hist(ls_test[:, 0],  alpha = 0.3, label = 'test ls') 
plt.xlim(0,1)
plt.legend()
plt.show()

# %% [markdown]
# ### PriorCVAE Model
#
# We define the PriorCVAE model, optimizer, and initialize the parameters of the model randomly.

# %%
conditional = args["conditional"]
out_dim = args["input_dim"]
hidden_dim = args["hidden_dim"]
latent_dim = args["latent_dim"]
batch_size = args["batch_size"]
num_iterations  = args["num_iterations"]
true_ls = args["true_ls"]
learning_rate = args["learning_rate"]
vae_var = args["vae_var"]

# %%
encoder = MLPEncoder(hidden_dim, latent_dim)
decoder = MLPDecoder(hidden_dim, out_dim)
model = VAE(encoder, decoder)

optimizer = optax.adam(learning_rate=learning_rate)
loss = SquaredSumAndKL(conditional=conditional, vae_var=vae_var)

# %% [markdown]
# ### Train the model
#
# Train the model and plot the train loss and the test loss.

# %%
trainer = VAETrainer(model, optimizer, loss=loss)
trainer.init_params(sample_y_train[0], c=sample_ls_train[0])

test_set = (x_test, y_test, ls_test)
loss_vals, test_vals, time_taken = trainer.train(gp_data_generator, test_set, num_iterations)

print(f'Training of {num_iterations} iterations took {round(time_taken)} seconds')
# Out:
# [    1] training loss: 11529.362, test loss: 93141.250
# [   11] training loss: 6001.112, test loss: 57725.944
# [   21] training loss: 4793.328, test loss: 48190.750
# [   31] training loss: 3310.808, test loss: 41640.577
# [   41] training loss: 3562.968, test loss: 36134.444
# [   51] training loss: 3152.750, test loss: 31000.205
# [   61] training loss: 2952.322, test loss: 28374.182
# [   71] training loss: 2562.064, test loss: 26774.894
# [   81] training loss: 2476.201, test loss: 25298.895
# [   91] training loss: 2146.002, test loss: 24195.028
# [  101] training loss: 2639.023, test loss: 23376.195
# [  111] training loss: 2010.546, test loss: 22358.987
# [  121] training loss: 2436.381, test loss: 21773.554
# [ 3591] training loss: 910.269, test loss: 9053.257
# [ 3601] training loss: 854.723, test loss: 8900.113
# [ 3611] training loss: 833.045, test loss: 8950.925
# [ 3621] training loss: 1019.030, test loss: 9021.271
# [ 3631] training loss: 889.152, test loss: 8908.088
# [ 3641] training loss: 817.211, test loss: 8960.965
# [ 3651] training loss: 867.697, test loss: 8871.321
# [ 3661] training loss: 811.316, test loss: 8912.355
# [ 3671] training loss: 847.339, test loss: 8948.372
# [ 3681] training loss: 775.886, test loss: 8953.372
# [ 3691] training loss: 885.731, test loss: 8873.183
# [ 3701] training loss: 805.620, test loss: 8907.960
# [ 3711] training loss: 947.130, test loss: 8916.616
# [ 3721] training loss: 909.951, test loss: 8952.680
# [ 3731] training loss: 997.203, test loss: 8956.219
# [ 3741] training loss: 856.670, test loss: 8934.681
# [ 3751] training loss: 992.912, test loss: 9000.092
# [ 3761] training loss: 945.396, test loss: 8950.719
# [ 3771] training loss: 724.846, test loss: 8878.733
# [ 3781] training loss: 906.381, test loss: 8937.264
# [ 3791] training loss: 1042.747, test loss: 8870.367
# [ 3801] training loss: 819.143, test loss: 8958.584
# [ 3811] training loss: 967.783, test loss: 8901.256
# [ 3821] training loss: 845.420, test loss: 8911.657
# [ 3831] training loss: 987.721, test loss: 8936.340
# [ 3841] training loss: 977.279, test loss: 8844.617
# [ 3851] training loss: 968.969, test loss: 8888.125
# [ 3861] training loss: 843.818, test loss: 8834.609
# [ 3871] training loss: 869.768, test loss: 8794.284
# [ 3881] training loss: 866.014, test loss: 8882.212
# [ 3891] training loss: 906.589, test loss: 8854.505
# [ 3901] training loss: 790.672, test loss: 8984.407
# [ 3911] training loss: 909.417, test loss: 8875.805
# [ 3921] training loss: 860.891, test loss: 8829.645
# [ 3931] training loss: 867.810, test loss: 8798.890
# [ 3941] training loss: 900.510, test loss: 8780.382
# [ 3951] training loss: 997.467, test loss: 8752.652
# [ 3961] training loss: 965.644, test loss: 8831.644
# [ 3971] training loss: 982.440, test loss: 8821.880
# [ 3981] training loss: 844.220, test loss: 8862.430
# [ 3991] training loss: 752.672, test loss: 8717.182
# Training of 4000 iterations took 1567 seconds

# %%
fig, axs = plt.subplots(1, 2, figsize=(8, 3))

axs[0].plot(range(len(loss_vals)), loss_vals)
axs[0].set_title('Training loss')

axs[1].plot(range(len(test_vals)), test_vals)
axs[1].set_title("Test loss")
# Out:
# Text(0.5, 1.0, 'Test loss')

# %% [markdown]
# ### Trained Decoder
#
# We plot a sample of trajectories from the trained decoder model.

# %%
decoder_params = trainer.state.params['decoder']
key = jax.random.PRNGKey(rnd.randint(0, 9999))
rng, z_rng, init_rng = random.split(key, 3)
z = random.normal(z_rng, (batch_size, latent_dim))

decoder = MLPDecoder(hidden_dim, out_dim)

c = true_ls * jnp.ones((z.shape[0], 1))
z_c = jnp.concatenate([z, c], axis=-1)
out = decoder.apply({'params': decoder_params}, z_c)             

fig, ax = plt.subplots(figsize=(4,3))
for i in range(15):
    ax.plot(sample_x_train[0], out[i,:])
ax.set_xlabel('$x$')
ax.set_ylabel('$y=f_{VAE}(x)$')
ax.set_title('Examples of learnt trajectories')

plt.show()

# %% [markdown]
# ### Inference with MCMC
#
# We randomly generate observations from the GP.

# %% [markdown]
# #### Generate data

# %%
x = sample_x_train[0]

rng_key_draw =  random.PRNGKey(1)
rng_key, rng_key_post, rng_key_preds, rng_key_draw = random.split(rng_key_draw, 4)

kernel = SquaredExponential(lengthscale=true_ls, variance=1.)
gp_predictive = Predictive(GP, num_samples=1)
draws = gp_predictive(rng_key_draw, kernel=kernel, x=x, jitter=1e-6, noise=True)

gp_draw = draws['f'].T
y_draw = draws['y'].T

# indices of data points
obs_idx = jnp.array([2, 13, 24, 39, 48])
y_obs = y_draw[obs_idx,0]
x_obs = x[np.array(obs_idx)]

plt.figure(figsize=(4,3))
plt.plot(x, gp_draw, label="ground truth", color="orange")
plt.scatter(x_obs, y_obs, color="red", label="observed data", s=60)
plt.title('Ground truth, corresponds to $ls$=' + str(args["true_ls"]))
# Out:
# Text(0.5, 1.0, 'Ground truth, corresponds to $ls$=0.2')

# %% [markdown]
# ### Numpyro model
#
# We define a Nupmyro model to run MCMC.

# %%
# add data to args. This is used by MCMC.
args["y_obs"] = y_obs
args["obs_idx"] = obs_idx

# %%
c = true_ls * jnp.ones((1, )) if conditional else None

mcmc_vae, mcmc_vae_samples, t_elapsed = run_mcmc_vae(rng_key_post, vae_mcmc_inference_model, args, decoder, 
                                                     decoder_params, c=c)
# Out:
#   0%|          | 0/5000 [00:00<?, ?it/s]
#   0%|          | 0/5000 [00:00<?, ?it/s]
#   0%|          | 0/5000 [00:00<?, ?it/s]
#   0%|          | 0/5000 [00:00<?, ?it/s]
#                 mean       std    median      5.0%     95.0%     n_eff     r_hat
#       f[0]     -0.69      0.18     -0.68     -0.98     -0.39  16636.07      1.00
#       f[1]     -0.71      0.18     -0.71     -1.02     -0.42  16856.55      1.00
#       f[2]     -0.74      0.18     -0.73     -1.05     -0.46  16740.08      1.00
#       f[3]     -0.76      0.19     -0.75     -1.08     -0.47  16664.67      1.00
#       f[4]     -0.80      0.18     -0.79     -1.09     -0.50  16826.63      1.00
#       f[5]     -0.81      0.19     -0.80     -1.12     -0.51  17040.28      1.00
#       f[6]     -0.86      0.18     -0.85     -1.16     -0.58  16922.70      1.00
#       f[7]     -0.89      0.17     -0.88     -1.18     -0.61  17037.00      1.00
#       f[8]     -0.94      0.16     -0.94     -1.21     -0.68  16845.09      1.00
#       f[9]     -0.98      0.16     -0.97     -1.22     -0.72  16773.75      1.00
#      f[10]     -1.03      0.15     -1.03     -1.27     -0.78  16732.52      1.00
#      f[11]     -1.07      0.14     -1.07     -1.30     -0.83  16522.57      1.00
#      f[12]     -1.13      0.14     -1.13     -1.36     -0.89  15404.13      1.00
#      f[13]     -1.17      0.14     -1.18     -1.40     -0.93  15463.80      1.00
#      f[14]     -1.19      0.14     -1.20     -1.42     -0.96  15411.47      1.00
#      f[15]     -1.25      0.15     -1.26     -1.49     -1.02  15473.81      1.00
#      f[16]     -1.32      0.16     -1.33     -1.57     -1.06  15726.98      1.00
#      f[17]     -1.36      0.17     -1.37     -1.61     -1.08  14963.39      1.00
#      f[18]     -1.37      0.17     -1.38     -1.63     -1.09  15525.04      1.00
#      f[19]     -1.39      0.17     -1.40     -1.66     -1.11  15776.50      1.00
#      z[18]     -0.00      1.00     -0.01     -1.58      1.69  21886.82      1.00
#      z[19]     -0.36      1.00     -0.36     -1.98      1.29  20426.77      1.00
#      z[20]      0.09      1.00      0.09     -1.55      1.75  20885.56      1.00
#      z[21]     -0.06      0.99     -0.06     -1.69      1.53  22588.78      1.00
#      z[22]      0.13      1.00      0.12     -1.46      1.78  23424.87      1.00
#      z[23]      0.07      0.99      0.07     -1.60      1.65  22862.47      1.00
#      z[24]     -0.08      0.76     -0.09     -1.32      1.23   5710.96      1.00
#      z[25]     -0.22      1.00     -0.21     -1.82      1.46  20901.89      1.00
#      z[26]     -0.08      1.00     -0.08     -1.72      1.56  21360.16      1.00
#      z[27]     -0.14      0.99     -0.14     -1.74      1.54  22392.55      1.00
#      z[28]      0.15      1.00      0.15     -1.47      1.79  21097.80      1.00
#      z[29]      0.19      1.00      0.18     -1.46      1.81  21623.30      1.00
#      z[30]     -0.11      0.98     -0.12     -1.72      1.50  20165.35      1.00
#      z[31]     -0.59      0.98     -0.59     -2.14      1.12  18410.03      1.00
#      z[32]      0.24      0.99      0.24     -1.34      1.93  19473.26      1.00
#      z[33]      0.06      1.02      0.06     -1.58      1.77  25340.66      1.00
#      z[34]     -0.36      0.93     -0.37     -1.89      1.17  14502.87      1.00
#      z[35]      0.02      1.01      0.02     -1.63      1.67  20850.00      1.00
#      z[36]     -0.11      1.01     -0.11     -1.73      1.59  23165.83      1.00
#      z[37]     -0.21      1.00     -0.21     -1.87      1.40  20721.51      1.00
#      z[38]      0.33      0.99      0.33     -1.31      1.93  20108.75      1.00
#      z[39]      0.04      1.00      0.04     -1.58      1.71  21368.96      1.00
#
# Number of divergences: 0
#
# MCMC elapsed time: 2 s
# Average ESS for all VAE-GP effects : 12831

# %% [markdown]
# ## Plotting
#
# We plot the trajectory after MCMC.

# %%
predictive = Predictive(vae_mcmc_inference_model, mcmc_vae_samples)

c = true_ls * jnp.ones((1, )) if conditional else None
predictions_vae = predictive(rng_key_preds, args, decoder, decoder_params, c)["f"]

mean_post_pred_vae = jnp.mean(predictions_vae, axis=0)
hpdi_post_pred_vae = hpdi(predictions_vae, 0.9)
percentiles_vae = np.percentile(predictions_vae, [5.0, 95.0], axis=0)

N_lines = 10

plt.figure(figsize=(4,3))
plt.plot(x, gp_draw, label="ground truth", color="orange")
plt.scatter(x_obs, y_obs, color="red", label="observed data", s=60)
plt.title('Ground truth, corresponds to $ls$=' + str(args["true_ls"]))

plt.plot(x, mean_post_pred_vae, label="predicted mean VAE")
plt.fill_between(x, percentiles_vae[0, :], percentiles_vae[1, :], alpha=0.3, interpolate=True, 
                 label="VAE posterior: 90% BCI")

y_min = min(np.concatenate([y_obs, mean_post_pred_vae, percentiles_vae[0, :]]))
y_max = max(np.concatenate([y_obs, mean_post_pred_vae, percentiles_vae[1, :]]))

plt.ylim([y_min, y_max])

plt.title('PriorCVAE inference')
# Out:
# Text(0.5, 1.0, 'PriorCVAE inference')
